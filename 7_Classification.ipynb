# %% [markdown]
# <a href="https://colab.research.google.com/github/rampage-rider/Machine-Learning-with-Iris-Dataset/blob/master/7_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris

# %%
data=load_iris()

# %%
print(data['DESCR'])
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %%
#In order to store it in a dataframe we neeed pandas
import pandas as pd

# %%
iris=pd.DataFrame(data.data)

# %%
iris
# Out:
#        0    1    2    3
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %%
data.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
#replacing the colomn names
iris.columns=data.feature_names

# %%
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
data.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
species=data.target

# %%
#first understand data. Exploritary Data Analysis
#that is plot graphs etc

# %%
#this single function will give all teh numeric analysed data
iris.boxplot()

# %%
import seaborn as sns
sns.pairplot(iris)

# %%
iris.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# count         150.000000        150.000000         150.000000        150.000000
# mean            5.843333          3.057333           3.758000          1.199333
# std             0.828066          0.435866           1.765298          0.762238
# min             4.300000          2.000000           1.000000          0.100000
# 25%             5.100000          2.800000           1.600000          0.300000
# 50%             5.800000          3.000000           4.350000          1.300000
# 75%             6.400000          3.300000           5.100000          1.800000
# max             7.900000          4.400000           6.900000          2.500000

# %%
iris.corr()
# Out:
#                    sepal length (cm)  ...  petal width (cm)
# sepal length (cm)           1.000000  ...          0.817941
# sepal width (cm)           -0.117570  ...         -0.366126
# petal length (cm)           0.871754  ...          0.962865
# petal width (cm)            0.817941  ...          1.000000
#
# [4 rows x 4 columns]

# %%
#create a new coloum species in the dataframe
iris['species']=species

# %%
iris.head
# Out:
# <bound method NDFrame.head of      sepal length (cm)  sepal width (cm)  ...  petal width (cm)  species
# 0                  5.1               3.5  ...               0.2        0
# 1                  4.9               3.0  ...               0.2        0
# 2                  4.7               3.2  ...               0.2        0
# 3                  4.6               3.1  ...               0.2        0
# 4                  5.0               3.6  ...               0.2        0
# ..                 ...               ...  ...               ...      ...
# 145                6.7               3.0  ...               2.3        2
# 146                6.3               2.5  ...               1.9        2
# 147                6.5               3.0  ...               2.0        2
# 148                6.2               3.4  ...               2.3        2
# 149                5.9               3.0  ...               1.8        2
#
# [150 rows x 5 columns]>

# %%
sns.pairplot(iris,hue='species')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /usr/local/lib/python3.6/dist-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
#we need to splitthe dataset into test and train
from sklearn.model_selection import train_test_split

# %%
train_test_split(iris,test_size=0.2)
# Out:
# [     sepal length (cm)  sepal width (cm)  ...  petal width (cm)  species
#  98                 5.1               2.5  ...               1.1        1
#  103                6.3               2.9  ...               1.8        2
#  64                 5.6               2.9  ...               1.3        1
#  96                 5.7               2.9  ...               1.3        1
#  136                6.3               3.4  ...               2.4        2
#  ..                 ...               ...  ...               ...      ...
#  118                7.7               2.6  ...               2.3        2
#  10                 5.4               3.7  ...               0.2        0
#  25                 5.0               3.0  ...               0.2        0
#  131                7.9               3.8  ...               2.0        2
#  123                6.3               2.7  ...               1.8        2
#
#  [120 rows x 5 columns],
# ...

# %%
#1st way to split
iris_train,iris_test=train_test_split(iris,test_size=0.2)

# %%
#2nd way to split
iris_train=iris.sample(frac=0.8)
iris_test=iris[~iris_train.index]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-4d77367f4d6d> in <module>()
#       1 iris_train=iris.sample(frac=0.8)
# ----> 2 iris_test=iris[~iris_train.index]
#
# TypeError: bad operand type for unary ~: 'Int64Index'

# %% [markdown]
# Metrrics for Classification:
#
# 1.accuracy_score
#
# 2.confusion_matrix
#
# 3.classification_report
#
# 4.Precision
#
# 5.Recall

# %%
x_train=iris_train.iloc[:,:-1]
y_train=iris_train.species

x_test=iris_test.iloc[:,:-1]
y_test=iris_test.species

# %%
lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred=lr.predict(x_train)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_train,y_pred)
# Out:
# 0.9583333333333334

# %%
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report, f1_score

# %%
lr.fit(x_test,y_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y1_pred=lr.predict(x_test)

# %%
accuracy_score(y_test,y1_pred)
# Out:
# 0.8

# %%
confusion_matrix(y_test,y1_pred)
# Out:
# array([[13,  0,  0],
#        [ 0,  0,  6],
#        [ 0,  0, 11]])

# %%
f1_score(y_test,y1_pred,average='micro')
# Out:
# 0.8000000000000002

# %%
print(classification_report(y_test,y1_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.00      0.00      0.00         6
#            2       0.65      1.00      0.79        11
#
#     accuracy                           0.80        30
#    macro avg       0.55      0.67      0.60        30
# weighted avg       0.67      0.80      0.72        30
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
x_train=iris_train.iloc[:,:-1]
y_train=iris_train.species

x_test=iris_test.iloc[:,:-1]
y_test=iris_test.species

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(x_test,y_test)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
y2_pred=dt.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y2_pred,y_test)
# Out:
# 1.0

# %%
# from internet
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(dt, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())
